# %%
import pandas as pd
import matplotlib as plt

df = pd.read_csv("/Users/talhamansari/diagnostic-equity-ml/projects/01-fairness-metrics/data/COMPASdata/compas-scores-raw.csv")
df.head(10)
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 5      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 6      50855         57181    51963    PRETRIAL    DAYES    DANIEL        NaN
# 7      50855         57181    51963    PRETRIAL    DAYES    DANIEL        NaN
# 8      50855         57181    51963    PRETRIAL    DAYES    DANIEL        NaN
# 9      50850         57176    51958    PRETRIAL     Debe  Mikerlie     George
#
#   Sex_Code_Text  Ethnic_Code_Text DateOfBirth  ...  RecSupervisionLevel  \
# ...

# %%
df.columns.tolist()
# Out:
# ['Person_ID',
#  'AssessmentID',
#  'Case_ID',
#  'Agency_Text',
#  'LastName',
#  'FirstName',
#  'MiddleName',
#  'Sex_Code_Text',
#  'Ethnic_Code_Text',
#  'DateOfBirth',
#  'ScaleSet_ID',
#  'ScaleSet',
#  'AssessmentReason',
#  'Language',
#  'LegalStatus',
#  'CustodyStatus',
#  'MaritalStatus',
#  'Screening_Date',
#  'RecSupervisionLevel',
#  'RecSupervisionLevelText',
#  'Scale_ID',
#  'DisplayText',
#  'RawScore',
#  'DecileScore',
#  'ScoreText',
#  'AssessmentType',
#  'IsCompleted',
#  'IsDeleted',
#  'predicted_high_risk']

# %%
df.shape
# Out:
# (60843, 28)

# %%
df = df[df['Ethnic_Code_Text'].isin(['African-American', 'Caucasian'])]
df['Ethnic_Code_Text'].value_counts()
# Out:
# Ethnic_Code_Text
# African-American    27018
# Caucasian           21783
# Name: count, dtype: int64

# %%
#high risk will be categorized medium or high recidivism scores PREDICTED HIGH RISK
df["predicted_high_risk"] = (df["RecSupervisionLevelText"].isin(["Medium", "High"])).astype(int)

# %%
#ACTUAL HIGH RISK
